# %%
# !git clone https://viettmab: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@github.com/viettmab/SemanticSegmentation

# %%
# !pip install -e file:///kaggle/working/SemanticSegmentation

# %%
import os
if not os.path.exists('./chkpt/'):
    os.makedirs('./chkpt/')
# !cp /kaggle/input/checkpoint/model_epoch_150.pt /kaggle/working/chkpt/
# !cp /kaggle/input/checkpoint/optim_epoch_150.pt /kaggle/working/chkpt/

# %%
MODEL_FLAGS="--model 'unet' --num_classes 19 --num_filters 64 --num_channels 3 --bilinear True --resnet False"
TRAIN_FLAGS="--epochs 150 --loss_type 'ce' --lr 0.005 --batch_size 4 --resume_step 150 --chkptfolder './chkpt/' --save_interval 50"
DATA_FLAGS="--data_dir '/kaggle/input/dataset/dataset' --augment True"
# !python /kaggle/working/SemanticSegmentation/scripts/train.py $MODEL_FLAGS $TRAIN_FLAGS $DATA_FLAGS

# %%
MODEL_FLAGS="--model 'unet' --num_classes 19 --num_filters 64 --num_channels 3 --bilinear True --resnet False --model_path './chkpt/model_epoch_300.pt'"
DATA_FLAGS="--data_dir '/kaggle/input/dataset/dataset' --batch_size 4"
# !python /kaggle/working/SemanticSegmentation/scripts/evaluate.py $MODEL_FLAGS $DATA_FLAGS

# %%
MODEL_FLAGS="--model 'unet' --num_classes 19 --num_filters 64 --num_channels 3 --bilinear True --resnet False --model_path './chkpt/model_epoch_300.pt'"
DATA_FLAGS="--data_dir '/kaggle/input/dataset/dataset' --batch_size 4"
# !python /kaggle/working/SemanticSegmentation/scripts/predict.py --result_folder './predict/' $MODEL_FLAGS $DATA_FLAGS

# %%
# !zip -r "ss.zip" "/kaggle/working"
from IPython.display import FileLink
FileLink(r'ss.zip')

# %%
# import shutil
# shutil.rmtree("/kaggle/working")

# %%
# %%writefile '/kaggle/working/SemanticSegmentation/scripts/train.py'

# %%
# %%writefile '/kaggle/working/SemanticSegmentation/model/unet.py'
